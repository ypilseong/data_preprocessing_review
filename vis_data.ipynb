# %%
import folium

map_folium = folium.Map(location=[33.532185616,126.842020683], zoom_start=17)
popup = folium.Popup('이로리', max_width=200)  # 마커를 클릭했을 때 '코리아IT아카데미'를 띄유는 팝업 창
folium.Marker(location=[33.532185616,126.842020683], popup=popup).add_to(map_folium)   
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

map_folium = folium.Map(location=[33.498001,126.4791111], zoom_start=17)
popup = folium.Popup('이로리', max_width=200)  # 마커를 클릭했을 때 '코리아IT아카데미'를 띄유는 팝업 창
folium.Marker(location=[33.498001,126.4791111], popup=popup).add_to(map_folium)   
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import requests

def geocoing(store_ad, type):
    apiurl = "https://api.vworld.kr/req/address?"
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": store_ad,
        "format": "json",
        "type": type, #road or parsel
        "key": "68847939-BE25-31AE-931E-08FB887AB0F1"
    }
    response = requests.get(apiurl, params=params)

    ad_json = response.json()

    return ad_json

# %%
store = '이로리'

ad_json = geocoing(store, type='road')
x_value = ad_json['response']['result']['point']['x']
y_value = ad_json['response']['result']['point']['y']
print(x_value, y_value)
# Out:
# 128.061548723 36.123821622

# %%
import pandas as pd
df = pd.read_csv('filtered_data.csv', sep=',', encoding='utf-8')

print(df[''])
# Out:
# 293

# %%
from pyproj import Proj, transform

# 주어진 좌표값
x = 911525.0
y = 1494525.0

# 입력 좌표계 (EPSG:5179)와 출력 좌표계 (EPSG:4326) 정의
inProj = Proj(init='epsg:5179') 
outProj = Proj(init='epsg:4326')

# 좌표 변환
lon, lat = transform(inProj, outProj, x, y)

print("변환된 좌표 (경도, 위도):", lon, lat)
#126.54816840894048 33.43880869463181 
#126.54789948633343 33.43880663019762
# Out:
# 변환된 좌표 (경도, 위도): 126.54816840894048 33.43880869463181
# /home/chuaie/anaconda3/envs/review/lib/python3.9/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/chuaie/anaconda3/envs/review/lib/python3.9/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
import pandas as pd

data = pd.read_csv('data/store_data.csv', sep=',', encoding='utf-8')
data_frame = data[['사업장명', '인허가일자', '상세영업상태명', '소재지전체주소', '도로명전체주소']]
data_frame.columns = ['store_name', 'permission_date', 'situation', 'address', 'address_road']
data_frame = data_frame.loc[data_frame.situation=='영업']




# data_frame['new_store_name'] = ''
# # 주소와 상호명 결합
# for i in range(len(data_frame)):
#     cols = ['store_name', 'address_road']
#     data_frame['new_store_name'] = data_frame[cols].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# # 날짜 데이터 표준화 및 특정기간 추출
# data_frame['permission_date'] = pd.to_datetime(data_frame['permission_date'], format='%Y%m%d')
# start_date = pd.to_datetime('2020-01-01')
# end_date = pd.to_datetime('2021-12-31')
# new_df_filter = data_frame[data_frame['permission_date'].between(start_date, end_date)]

# new_df_filter.to_csv('data/filtered_data.csv', index=False)

# print(len(new_df_filter))
# Out:
#         store_name  permission_date situation  \
# 0           탑동에이치지         20181129        영업
# 1         에릭스에스프레소         20181102        영업
# 2         일품순두부한림점         20190107        영업
# 3       김복남맥주제주아라점         20190107        영업
# 4            봉플라봉뱅         20190107        영업
# ...            ...              ...       ...
# 45912  제주밭담샾어멍아방카페         20230921        영업
# 45913           연돈         20230926        영업
# 45914          가시림         20230926        영업
# 45915         올드타운         20230925        영업
# 45916      돌고래푸드트럭         20230927        영업
#
#                                            address  \
# 0                          제주특별자치도 제주시 삼도이동 1120-2
# 1                     제주특별자치도 제주시 구좌읍 세화리 1397-6번지
# 2                     제주특별자치도 제주시 한림읍 대림리 1845-2번지
# 3                            제주특별자치도 제주시 아라일동 6139
# 4                    제주특별자치도 제주시 연동 312-57번지 정인하우스
# ...                                            ...
# ...

# %%
data_frame['new_store_name'] = ''
# 주소와 상호명 결합
for i in range(len(data_frame)):
    cols = ['store_name', 'address_road']
    data_frame['new_store_name'] = data_frame[cols].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# 날짜 데이터 표준화 및 특정기간 추출
data_frame['permission_date'] = pd.to_datetime(data_frame['permission_date'], format='%Y%m%d')
start_date = pd.to_datetime('2020-01-01')
end_date = pd.to_datetime('2021-12-31')
new_df_filter = data_frame[data_frame['permission_date'].between(start_date, end_date)]

new_df_filter.to_csv('data/filtered_data.csv', index=False)

print(len(new_df_filter))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 for i in range(len(data_frame)):
#       4     cols = ['store_name', 'address_road']
# ----> 5     data_frame['new_store_name'] = data_frame[cols].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
#       7 # 날짜 데이터 표준화 및 특정기간 추출
#       8 data_frame['permission_date'] = pd.to_datetime(data_frame['permission_date'], format='%Y%m%d')
#
# File ~/anaconda3/envs/review/lib/python3.9/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# ...
